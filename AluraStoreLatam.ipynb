# %% [markdown]
# <a href="https://colab.research.google.com/github/diego2003-her14/an-lisis-de-alura-store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
#se realiza el analisis de lo que produce las empresas

ingresos_tiendas = int(tienda['Precio'].sum())
ingresos_tiendas2 = int(tienda2['Precio'].sum())
ingresos_tiendas3 = int(tienda3['Precio'].sum())
ingresos_tiendas4 = int(tienda4['Precio'].sum())

# print() para mostrar
print(f"Ingresos de la tienda 1: {ingresos_tiendas}")
print(f"Ingresos de la tienda 2: {ingresos_tiendas2}")
print(f"Ingresos de la tienda 3: {ingresos_tiendas3}")
print(f"Ingresos de la tienda 4: {ingresos_tiendas4}")
# Out:
# Ingresos de la tienda 1: 1150880400
# Ingresos de la tienda 2: 1116343500
# Ingresos de la tienda 3: 1098019600
# Ingresos de la tienda 4: 1038375700

# %%
nombre = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [ingresos_tiendas, ingresos_tiendas2, ingresos_tiendas3, ingresos_tiendas4]

plt.bar(nombre, ingresos)
plt.title('Ingresos por tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingresos')
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
cal_promedio = tienda['Calificación'].mean()
print(f"La calificación promedio de la tienda es: {cal_promedio}")

cal_promedio2 = tienda2['Calificación'].mean()
print(f"La calificación promedio de la tienda es: {cal_promedio2}")

cal_promedio3 = tienda3['Calificación'].mean()
print(f"La calificación promedio de la tienda es: {cal_promedio3}")

cal_promedio4 = tienda4['Calificación'].mean()
print(f"La calificación promedio de la tienda es: {cal_promedio4}")
# Out:
# La calificación promedio de la tienda es: 3.976685036032217
# La calificación promedio de la tienda es: 4.037303942348453
# La calificación promedio de la tienda es: 4.048325561678677
# La calificación promedio de la tienda es: 3.9957591178965224

# %%
plt.pie([cal_promedio, cal_promedio2, cal_promedio3, cal_promedio4], labels=['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], autopct='%1.1f%%')
plt.title('Calificación promedio por tienda')
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
print('Costo de envio de cada tienda')
print(f'Tienda 1: {tienda["Costo de envío"].mean()}')
print(f'Tienda 2: {tienda2["Costo de envío"].mean()}')
print(f'Tienda 3: {tienda3["Costo de envío"].mean()}')
print(f'Tienda 4: {tienda4["Costo de envío"].mean()  }')

# Creamos una figura y un objeto de ejes
fig, ax = plt.subplots()

# Graficamos los datos para cada tienda
ax.scatter(tienda.index, tienda['Costo de envío'], label='Tienda 1')
ax.scatter(tienda2.index, tienda2['Costo de envío'], label='Tienda 2')
ax.scatter(tienda3.index, tienda3['Costo de envío'], label='Tienda 3')
ax.scatter(tienda4.index, tienda4['Costo de envío'], label='Tienda 4')

# Personalizamos la gráfica
plt.title('Costo de envío por tienda')
plt.xlabel('Índice')  # Usamos el índice como eje x para simplificar
plt.ylabel('Costo de envío')
plt.legend()

plt.show()
# Out:
# Costo de envio de cada tienda
# Tienda 1: 26018.60958033065
# Tienda 2: 25216.235693090293
# Tienda 3: 24805.680373039424
# Tienda 4: 23459.457167090754
